# %% [markdown]
# <a href="https://colab.research.google.com/github/Aksinhaa/ColabFold/blob/main/mtDNA_ananlysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%bash
# # Install Miniconda
# wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# bash Miniconda3-latest-Linux-x86_64.sh -b -p /usr/local/miniconda
#
# # Initialize conda
# source /usr/local/miniconda/etc/profile.d/conda.sh
#
# # Accept Terms of Service
# conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
# conda tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#
# # Add channels
# conda config --add channels defaults
# conda config --add channels bioconda
# conda config --add channels conda-forge
# Out:
# PREFIX=/usr/local/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local/miniconda
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# ...

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# conda create -y -n mito_env seqprep prinseq bbmap fastx_toolkit
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# done
# Channels:
#  - conda-forge
#  - bioconda
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/miniconda/envs/mito_env
#
#   added / updated specs:
#     - bbmap
#     - fastx_toolkit
#     - prinseq
#     - seqprep
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           20_gnu          28 KB  conda-forge
#     alsa-lib-1.2.15.3          |       hb03c661_0         571 KB  conda-forge
#     bbmap-39.81                |       h9b5c0a0_1        88.8 MB  bioconda
#     bzip2-1.0.8                |       hda65f42_9         254 KB  conda-forge
#     c-ares-1.34.6              |       hb03c661_0         203 KB  conda-forge
#     ca-certificates-2026.4.22  |       hbd8a1cb_0         128 KB  conda-forge
# ...

# %%
# %%bash
# ls /usr/local/miniconda/envs/mito_env/bin/prinseq-
# Out:
# ace2sam
# addadapters.sh
# addssu.sh
# adig
# adjusthomopolymers.sh
# ahost
# alignrandom.sh
# alltoall.sh
# analyzeaccession.sh
# analyzegenes.sh
# analyzesketchresults.sh
# annotate
# annot-tsv
# applyvariants.sh
# a_sample_mt.sh
# aserver
# assistant
# balsam
# bamlinestreamer.sh
# bandedaligner.sh
# bandedplusaligner.sh
# bbcms.sh
# bbcountunique.sh
# bbcrisprfinder.sh
# bbdukOld.sh
# bbduk.sh
# bbdukS.sh
# bbest.sh
# bbfakereads.sh
# bbmap.sh
# bbmapskimmer.sh
# bbmask.sh
# bbmerge-auto.sh
# bbmerge.sh
# bbnorm.sh
# bbrealign.sh
# bbrename.sh
# bbsketch.sh
# bbsort.sh
# bbsplitpairs.sh
# bbsplit.sh
# bbstats.sh
# bbversion.sh
# bbwrap.sh
# bdf2gdfont.pl
# bdftogd
# bgzip
# blast2sam.pl
# bloomfilterparser.sh
# bloomfilter.sh
# bowtie2sam.pl
# build_env_setup.sh
# bunzip2
# bzcat
# bzcmp
# bzdiff
# bzegrep
# bzfgrep
# bzgrep
# bzip2
# bzip2recover
# bzless
# bzmore
# cairo-trace
# calcmem.sh
# calctruequality.sh
# callgenes.sh
# callpeaks.sh
# callvariants2.sh
# callvariants.sh
# ...

# %%
# %%bash
#
# source /usr/local/miniconda/etc/profile.d/conda.sh
#
# conda activate mito_env
#
# git clone https://github.com/mpieva/mapping-iterative-assembler.git
# Out:
# Cloning into 'mapping-iterative-assembler'...

# %%
# %%bash
# mkdir -p /content/{fastq_files,reference}
# cd /content
# pwd
# Out:
# /content

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
#
# conda activate mito_env
# cd /content/fastq_files/
#
# wget -nc ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR127/085/SRR12727185/SRR12727185_1.fastq.gz
# wget -nc ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR127/085/SRR12727185/SRR12727185_2.fastq.gz
# Out:
# --2026-05-09 04:34:37--  ftp://ftp.sra.ebi.ac.uk/vol1/fastq/SRR127/085/SRR12727185/SRR12727185_1.fastq.gz
#            => ‘SRR12727185_1.fastq.gz’
# Resolving ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)... 193.62.193.165
# Connecting to ftp.sra.ebi.ac.uk (ftp.sra.ebi.ac.uk)|193.62.193.165|:21... connected.
# Logging in as anonymous ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /vol1/fastq/SRR127/085/SRR12727185 ... done.
# ==> SIZE SRR12727185_1.fastq.gz ... 548892016
# ==> PASV ... done.    ==> RETR SRR12727185_1.fastq.gz ... done.
# Length: 548892016 (523M) (unauthoritative)
#
#      0K .......... .......... .......... .......... ..........  0%  109K 81m48s
#     50K .......... .......... .......... .......... ..........  0%  506K 49m44s
#    100K .......... .......... .......... .......... ..........  0%  134M 33m10s
#    150K .......... .......... .......... .......... ..........  0%  504K 29m18s
# ...

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# cd /content/reference
# wget -O KM659865.1.fasta \
# "https://www.ncbi.nlm.nih.gov/search/api/download-sequence/?db=nuccore&id=KM659865.1"
# Out:
# --2026-05-09 04:35:16--  https://www.ncbi.nlm.nih.gov/search/api/download-sequence/?db=nuccore&id=KM659865.1
# Resolving www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)... 130.14.29.110, 2607:f220:41e:4290::110
# Connecting to www.ncbi.nlm.nih.gov (www.ncbi.nlm.nih.gov)|130.14.29.110|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/plain]
# Saving to: ‘KM659865.1.fasta’
#
#      0K .......... ......                                       668K=0.03s
#
# 2026-05-09 04:35:16 (668 KB/s) - ‘KM659865.1.fasta’ saved [17247]

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# cd /content
# wget https://raw.githubusercontent.com/Paleogenomics/DNA-Post-Processing/master/mito_assembly_pipeline.sh
# chmod +x mito_assembly_pipeline.sh
# Out:
# --2026-05-09 04:35:16--  https://raw.githubusercontent.com/Paleogenomics/DNA-Post-Processing/master/mito_assembly_pipeline.sh
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7913 (7.7K) [text/plain]
# Saving to: ‘mito_assembly_pipeline.sh’
#
#      0K .......                                               100% 54.2M=0s
#
# 2026-05-09 04:35:17 (54.2 MB/s) - ‘mito_assembly_pipeline.sh’ saved [7913/7913]

# %%
# %%bash
# sed -i 's#MIA=/path/to/mia-1.0/src#MIA=/content/mapping-iterative-assembler/src#g' mito_assembly_pipeline.sh
# sed -i 's#PRINSEQ=/path/to/prinseq#PRINSEQ=/usr/local/miniconda/envs/mito_env/bin#g' mito_assembly_pipeline.sh
# sed -i 's#BBPATH=/path/to/bbmap#BBPATH=/usr/local/miniconda/envs/mito_env/bin#g' mito_assembly_pipeline.sh
# sed -i 's#FASTX_TOOLKIT=/path/to/fastx_toolkit-0.0.13.2/src#FASTX_TOOLKIT=/usr/local/miniconda/envs/mito_env/bin#g' mito_assembly_pipeline.sh
#
# cat mito_assembly_pipeline.sh
# Out:
# #!/bin/bash
# # 31 Oct 2019
# # A. Vershinina avershin@ucsc.edu https://github.com/avershinina
# # Reference-guided aseembly of ancient mitochondrial genome
# # Quickstart: ./mito_assembly_pipeline.sh path/to/sample.R1.fastq.gz path/to/sample.R2.fastq.gz samplename
#
# ###################
# # README
# ###################
#
# # This script complements the paper by Vershinina et al 201X "The case of an arctic wild ass highlights the utility of ancient DNA for validating problematic identifications in museum collections", currently under review at Molecular Ecology Resources.
# # This script is a pipeline that utilizes a set of bioinformatic tools to process anicent DNA sequencing data with the aim of assembling a complete mitochondrial genome using a reference. This script works only for paired end Illumina data.
#
# # To run the pipeline:
# ...

# %%
# %%bash
# source /usr/local/miniconda/etc/profile.d/conda.sh
# ./mito_assembly_pipeline.sh SRR12727185_1.fastq.gz SRR12727185_2.fastq.gz test_data_cynopterus
# Out:
# ---------------------------
# Starting the pipeline
# ---------------------------
# ---------------------------
# Seqprep and bbmap have finished running
# ---------------------------
# ---------------------------
# Prinseq and fastx have finished running
# Starting mito assembly
# ---------------------------
# ---------------------------
# Mito assembly has finished running
# ---------------------------
# Everything has finished running
# MIA assembly stats:
# test_data_cynopterus.name_mito.maln.F.mia_stats.txt
# gzip: seqprep_output/test_data_cynopterus_merged.fastq.gz: No such file or directory
# Can't open perl script "/path/to/prinseq/prinseq-lite.pl": No such file or directory
# ./mito_assembly_pipeline.sh: line 99: /path/to/bbmap/sh/reformat.sh: No such file or directory
# gzip: seqprep_output/test_data_cynopterus_unmerged_combined.fastq.gz: No such file or directory
# Can't open perl script "/path/to/prinseq/prinseq-lite.pl": No such file or directory
# ...
