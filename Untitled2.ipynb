# %% [markdown]
# <a href="https://colab.research.google.com/github/Aksinhaa/ColabFold/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir test

# %% [markdown]
# **sajdhashbfkbfkdsbfj**

# %%
# !printf "1 2 3 4\n5 6 7 8" >table.txt
# !cat table.txt
